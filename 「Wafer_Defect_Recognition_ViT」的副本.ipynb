# %% [markdown]
# <a href="https://colab.research.google.com/github/hsiaoyouting/ResNet50_Wafer_Map_Recognition.ipynb/blob/main/%E3%80%8CWafer_Defect_Recognition_ViT%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
co1d7era_mixedtype_wafer_defect_datasets_path = kagglehub.dataset_download('co1d7era/mixedtype-wafer-defect-datasets')

print('Data source import complete.')
# Out:
# Downloading to /root/.cache/kagglehub/datasets/co1d7era/mixedtype-wafer-defect-datasets/4.archive...
# 100%|██████████| 21.8M/21.8M [00:02<00:00, 9.48MB/s]
# Extracting files...
# Data source import complete.

# %% [markdown]
# # Visual Transformer for mixed-type wafer defect pattern recognition
#
# ### [https://github.com/PanithanS/Visual-Transformer-Mixed-type-Wafers-Defect-Recognition](https://github.com/PanithanS/Visual-Transformer-Mixed-type-Wafers-Defect-Recognition)
#
# ![](https://private-user-images.githubusercontent.com/83627892/271644591-cd9f6527-e2dc-4411-89c1-8b5988cb321f.png?jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....eSgdNr2sMgE0Gh2tlAQdnptn-PPkrwK7jGHv_MYE8KA)

# %%
# !pip install tensorflow
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.13/dist-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from tensorflow) (26.3)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.83.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from astunparse>=1.6.0->tensorflow) (0.48.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.13/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.13/dist-packages (from keras>=3.10.0->tensorflow) (0.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# ERROR: Could not find a version that satisfies the requirement tensorflow-addons (from versions: none)
# ERROR: No matching distribution found for tensorflow-addons

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
class data_loader:

    def __init__(self, dataset_path, vis=False):

        """this funtion is to initialize the data_loader class

        Args:
            dataset_path(string): the dataset object address

        """

        self.dataset_path = dataset_path
        self.is_vis = vis

        # The list that use to translate the label to defects type
        self.label_keys = ["Center, ", "Donut, ", "Edge_Loc, ", "Edge_Ring, ",
                           "Loc, ", "Near_Full, ", "Scratch, ", "Random, "]

    def load_data(self):

        """this funtion is to load data to the vaiable "self.train" and "self.label"  """

        self.data = np.load(self.dataset_path)
        self.train = self.data["arr_0"]
        self.label = self.data["arr_1"]

        #print("data_x",np.shape(self.train))
        print("MixedWM38:", np.shape(self.label)[0], 'wafer loaded')

    def prep_data(self):

        """this funtion is to do train_test_split and format the data"""

        self.x_train, self.x_test, self.y_train, self.y_test = train_test_split(self.train, self.label, test_size = 0.2)

        # Make sure images have shape (Batch, image_size, image_size, channel)
        self.x_train = np.expand_dims(self.x_train, -1)
        self.x_test = np.expand_dims(self.x_test, -1)

        # Convert class vectors to right format
        self.y_train = tf.convert_to_tensor(np.array(self.y_train))
        self.y_test = tf.convert_to_tensor(np.array(self.y_test))

    def read_label(self, label, defect_types =''):

        """this funtion is to translate the label into defect_types

        Args:
            label(list): the label that indicate type of  defect, for instance [0 1 0 1 0 0 0 1]

        Return:
            defect_types(string): the string that indicate defect type
        """

        if np.sum(label) == 0:
            defect_types = 'Normal wafer'

        else:
            for digit in range(np.shape(label)[0]):

                if label[digit] == 1:

                    defect_types = defect_types + self.label_keys[digit]

        return defect_types

    def see_wafer(self, wafer_num):

        """this funtion is to see the defect pattern in idicated by wafer number


        Args:
            wafer_num(float): the index of loaded data in self.train

        Return:
            plot(oject): the plot image
        """

        defect_types = self.read_label(self.label[wafer_num])

        plt.title("wafer #"+str(wafer_num))
        plt.imshow(self.train[wafer_num])
        plt.colorbar()
        plt.show()

        print("Defect types=", defect_types)
        print("Labeled as:", self.label[wafer_num])

    def get_data(self):

        """this funtion is get the loaded data

        Return:
            x_train(array): image of defect pattern for model training
            x_test(array): image of defect pattern for model validation
            y_train(tensor): label of defect pattern for model training
            y_test(tensor): label of defect pattern for model validation
        """

        self.load_data()
        self.prep_data()

        return self.x_train, self.x_test, self.y_train, self.y_test

# %% [markdown]
# ## [WaferMap Dataset: MixedWM38](https://github.com/Junliangwangdhu/WaferMap)

# %%
dataset_path = '/kaggle/input/mixedtype-wafer-defect-datasets/Wafer_Map_Datasets.npz'

A1 = data_loader(dataset_path, vis=True)
x_train, x_test, y_train, y_test = A1.get_data()
# Out:
# MixedWM38: 38015 wafer loaded

# %%
# 2 type
A1.see_wafer(20000)
# Out:
# Defect types= Donut, Edge_Ring, Loc,
# Labeled as: [0 1 0 1 1 0 0 0]

# %%
# 2 type
A1.see_wafer(36015)
# Out:
# Defect types= Edge_Ring, Scratch,
# Labeled as: [0 0 0 1 0 0 1 0]

# %%
# 4 type
A1.see_wafer(19005)
# Out:
# Defect types= Donut, Edge_Ring, Loc, Scratch,
# Labeled as: [0 1 0 1 1 0 1 0]

# %%
# Normal
A1.see_wafer(33866)
# Out:
# Defect types= Normal wafer
# Labeled as: [0 0 0 0 0 0 0 0]

# %%
# 1 type
A1.see_wafer(12000)
# Out:
# Defect types= Center,
# Labeled as: [1 0 0 0 0 0 0 0]

# %%
# 1 type
A1.see_wafer(24000)
# Out:
# Defect types= Donut,
# Labeled as: [0 1 0 0 0 0 0 0]

# %% [markdown]
# #  Visual transformer model and training

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

class vis_transformer:

    def __init__(self, x_train, x_test, y_train, y_test):

        """this funtion is to initialize the vis_transformer class

        Args:
            x_train(array): image of defect pattern for model training
            x_test(array): image of defect pattern for model validation
            y_train(tensor): label of defect pattern for model training
            y_test(tensor): label of defect pattern for model validation

        """

        self.x_train = x_train
        self.x_test = x_test
        self.y_train = y_train
        self.y_test = y_test

        (_, self.image_size, b, c) = np.shape(self.x_train) # We'll resize input images to this size

        self.input_shape = (self.image_size, self.image_size, c)

        self.label_size = np.shape(y_test)[1]
        self.patch_size = 13  # Size of the patches to be extract from the input images
        self.num_patches = (self.image_size // self.patch_size) ** 2

        self.projection_dim = 96
        self.num_heads = 4
        self.transformer_units = [self.projection_dim * 2, self.projection_dim,]  # Size of the transformer layers
        self.transformer_layers = 16
        self.mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

    def augmentation(self):

        """this funtion is as oject function to do data augmentation"""

        data_augmentation = keras.Sequential(
            [
                tf.keras.layers.experimental.preprocessing.Normalization(),
                tf.keras.layers.experimental.preprocessing.RandomRotation(factor=0.02),
                tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=0.2, width_factor=0.2),
            ], name="data_augmentation",)

        # Compute the mean and the variance of the training data for normalization.
        data_augmentation.layers[0].adapt(self.x_train)


    def mlp(self, x, hidden_units, dropout_rate):

        """this funtion is multilayer perceptron(mpl) head

        Args:
            hidden_units(list): the hidden dimenstion of the mpl
            dropout_rate(float): dropout rate of mpl

        """

        for units in hidden_units:

            x = layers.Dense(units, activation=tf.nn.gelu)(x)
            x = layers.Dropout(dropout_rate)(x)

        return x

    def get_patches(self, images):

        """this funtion is to split image into patches of "self.patch_size" x "self.patch_size"

        Args:
            images(array): the images to applied patches

        Return:
            patches(array): the image patches

        """

        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]

        patches = tf.reshape(patches, [batch_size, -1, patch_dims])

        return patches

    def see_patches(self, image, num_image):

        patches = self.get_patches(image)

        image = self.x_train[num_image]
        plt.imshow(image)
        plt.clim(0,2)
        plt.axis("off")

        resized_image = tf.image.resize(tf.convert_to_tensor([image]), size=(self.image_size, self.image_size))

        patches = self.get_patches(resized_image)

        print(f"Image size: {self.image_size} X {self.image_size}")
        print(f"Patch size: {self.patch_size} X {self.patch_size}")
        print(f"Patches per image: {patches.shape[1]}")
        print(f"Elements per patch: {patches.shape[-1]}")
        print(f"Num patch:", self.num_patches)

        n = int(np.sqrt(patches.shape[1]))
        plt.figure(figsize=(4, 4))
        for i, patch in enumerate(patches[0]):
            ax = plt.subplot(n, n, i + 1)
            patch_img = tf.reshape(patch, (self.patch_size, self.patch_size))
            plt.imshow(patch_img.numpy())
            plt.clim(0,2)
            plt.axis("off")

        print(np.shape(patches))

    def get_patchencoder(self, patch):

        """this funtion is encode the patch as projection on dense layer with position embedding

        Args:
            patch(array): the images to applied patches

        Return:
            encoded(oject): the encoded patches

        """

        self.projection = layers.Dense(units=self.projection_dim)
        self.position_embedding = layers.Embedding(input_dim=self.num_patches, output_dim=self.projection_dim)

        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)

        return encoded

    def create_model(self):

        """this funtion is to create visual transformer

        Return:
            model(object): visual transformer model

        """
        inputs = layers.Input(shape=(52,52,1))

        # Augment data.
        images = inputs #data_augmentation(inputs)

        # Create patches using the new Patches layer
        patches_extractor = Patches(self.patch_size)
        patches = patches_extractor(images)

        # Encode patches.
        encoded_patches = self.get_patchencoder(patches)

        #print(np.shape(encoded_patches))

        # Create multiple layers of the Transformer block.

        for _ in range(self.transformer_layers):

            # Layer normalization 1.
            x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)

            # Create a multi-head attention layer.
            attention_output = layers.MultiHeadAttention(num_heads=self.num_heads, key_dim=self.projection_dim, dropout=0.1)(x1, x1)

            #print(np.shape(attention_output))

            # Skip connection 1.
            x2 = layers.Add()([attention_output, encoded_patches])

            # Layer normalization 2.
            x3 = layers.LayerNormalization(epsilon=1e-6)(x2)

            # MLP.
            x3 = self.mlp(x3, hidden_units=self.transformer_units, dropout_rate=0.1)

            # Skip connection 2.
            encoded_patches = layers.Add()([x3, x2])

        #print('encoded_patches:', np.shape(encoded_patches))

        # Create a [batch_size, projection_dim] tensor.
        representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        representation = layers.Flatten()(representation)
        representation = layers.Dropout(0.2)(representation)

        #print('representation:', np.shape(representation))

        # Add MLP.
        features = self.mlp(representation, hidden_units=self.mlp_head_units, dropout_rate=0.5)

        #print('features:', np.shape(features))

        # Classify outputs.
        #features = layers.Dense(label_size*2, kernel_initializer='he_uniform', activation='relu')(features)
        logits = layers.Dense(self.label_size, activation='sigmoid')(features)

        # Create the Keras model.
        model = keras.Model(inputs=inputs, outputs=logits)

        #print(model.summary())

        return model


    def train_model(self, batch_size = 512, num_epochs = 40, save_path='none'):

        """this funtion is to train the visual transformer model

        Args:
            batch_size(float): training batch_size
            num_epochs(float): training num_epochs
            num_epochs(string): model oject address, and it will be use for history saving file too

        Return:
            history(dict): training history

        """
        self.model_vit = self.create_model()

        if save_path != 'none':
            print("set model-saving: " + save_path )
            print("set history-saving: " + save_path+'_history' )

        lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-3, decay_steps=10000, decay_rate=0.9)
        opt = tf.keras.optimizers.Adam(lr_schedule)

        self.model_vit.compile(optimizer=opt, loss='binary_crossentropy',metrics=[keras.metrics.BinaryAccuracy(name="accuracy")])

        checkpoint_filepath = "./tmp/checkpoint.weights.h5"
        checkpoint_callback = keras.callbacks.ModelCheckpoint(
            checkpoint_filepath,
            monitor="val_accuracy",
            save_best_only=True,
            save_weights_only=True,
        )

        history = self.model_vit.fit(
            x=self.x_train,
            y=self.y_train,
            batch_size=batch_size,
            epochs=num_epochs,
            validation_split=0.1,
            callbacks=[checkpoint_callback],
        )

        self.model_vit.load_weights(checkpoint_filepath)
        _, accuracy = self.model_vit.evaluate(self.x_test, self.y_test)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        if save_path!= 'none':
            self.model_vit.save_weights(save_path)

            with open(save_path+'_history', 'wb') as file_pi:
                pickle.dump(history.history, file_pi)

        return history

    def load_model(self, path, plot=False):

        """this funtion is to load the training weight of the visual transformer model

        Args:
            path(string): model oject address, and it will be use for history loading file too

        Return:
            self.model_vit(oject): the visual transformer model with loaded weight

        """

        try:
            del self.model_vit
        except:
            print("load model")

        self.model_vit = self.create_model()
        self.model_vit.load_weights(path)
        lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-3, decay_steps=10000, decay_rate=0.9)
        opt = tf.keras.optimizers.Adam(lr_schedule)

        self.model_vit.compile(optimizer=opt, loss='binary_crossentropy',metrics=[keras.metrics.BinaryAccuracy(name="accuracy")])

        with open(path+'_history', "rb") as file_pi:
            history = pickle.load(file_pi)

        if (plot):
            # Plot training and validation loss
            plt.figure(dpi=100)  # You can adjust the figure size if needed

            plt.plot(history['val_accuracy'], label='Validation accuracy')
            plt.plot(history['accuracy'], label='Training accuracy')

            plt.plot(history['val_loss'], label='Validation loss')
            plt.plot(history['loss'], label='Training Loss')

            plt.legend()
            plt.xlabel('Epochs')
            plt.ylabel('Loss')
            plt.show()

        return self.model_vit

    def model_eval(self, model, x_test, y_test):

        """this funtion is for model accuracy checking"""

        loss, accuracy = model.evaluate(x_test, y_test)

        print("loss: ", loss, "accuracy: ", accuracy )
        print(f"Test accuracy: {round(accuracy*100, 2)}%")

# %% [markdown]
# ###  Briefly check on the patches

# %%
A_test_patches = vis_transformer(x_train, x_test, y_train, y_test)
A_test_patches.see_patches(x_test, num_image=250)
# Out:
# Image size: 52 X 52
# Patch size: 13 X 13
# Patches per image: 16
# Elements per patch: 169
# Num patch: 16
# (1, 16, 169)

# %% [markdown]
# ### ViT intitialize to train a new model or create the model for weight loading

# %%
# !git clone https://github.com/PanithanS/Wafers-Defect-Recognition-using-Visual-Transformer
# %cd Wafers-Defect-Recognition-using-Visual-Transformer
# Out:
# Cloning into 'Wafers-Defect-Recognition-using-Visual-Transformer'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 173 (delta 16), reused 0 (delta 0), pack-reused 134 (from 1)
# Receiving objects: 100% (173/173), 181.57 KiB | 4.66 MiB/s, done.
# Resolving deltas: 100% (64/64), done.
# /content/Wafers-Defect-Recognition-using-Visual-Transformer

# %% [markdown]
# ## Training model

# %%
A2 = vis_transformer(x_train, x_test, y_train, y_test)

# model weight file to be loaded
path = "./model_vit.weights.h5"

# If train new model
history = A2.train_model(batch_size = 512, num_epochs = 45, save_path=path)
# Out:
# set model-saving: ./model_vit.weights.h5
# set history-saving: ./model_vit.weights.h5_history
# Epoch 1/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.6868 - loss: 0.5892 - val_accuracy: 0.7128 - val_loss: 0.5039
# Epoch 2/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.7037 - loss: 0.5176 - val_accuracy: 0.7129 - val_loss: 0.5072
# Epoch 3/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.7078 - loss: 0.5094 - val_accuracy: 0.7416 - val_loss: 0.4938
# Epoch 4/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.7468 - loss: 0.4444 - val_accuracy: 0.8249 - val_loss: 0.3479
# Epoch 5/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 21s 198ms/step - accuracy: 0.8277 - loss: 0.3279 - val_accuracy: 0.8800 - val_loss: 0.2477
# Epoch 6/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.8872 - loss: 0.2383 - val_accuracy: 0.9293 - val_loss: 0.1768
# Epoch 7/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9181 - loss: 0.1917 - val_accuracy: 0.9514 - val_loss: 0.1370
# Epoch 8/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.9405 - loss: 0.1507 - val_accuracy: 0.9635 - val_loss: 0.1018
# Epoch 9/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.9543 - loss: 0.1209 - val_accuracy: 0.9681 - val_loss: 0.0898
# Epoch 10/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9603 - loss: 0.1069 - val_accuracy: 0.9668 - val_loss: 0.0906
# Epoch 11/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.9665 - loss: 0.0931 - val_accuracy: 0.9726 - val_loss: 0.0782
# Epoch 12/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.9720 - loss: 0.0793 - val_accuracy: 0.9706 - val_loss: 0.0828
# Epoch 13/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.9720 - loss: 0.0793 - val_accuracy: 0.9788 - val_loss: 0.0603
# Epoch 14/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 21s 193ms/step - accuracy: 0.9748 - loss: 0.0718 - val_accuracy: 0.9813 - val_loss: 0.0532
# Epoch 15/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.9787 - loss: 0.0611 - val_accuracy: 0.9777 - val_loss: 0.0659
# Epoch 16/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9783 - loss: 0.0631 - val_accuracy: 0.9770 - val_loss: 0.0634
# Epoch 17/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 200ms/step - accuracy: 0.9818 - loss: 0.0532 - val_accuracy: 0.9823 - val_loss: 0.0569
# Epoch 18/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.9823 - loss: 0.0526 - val_accuracy: 0.9827 - val_loss: 0.0503
# Epoch 19/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9825 - loss: 0.0518 - val_accuracy: 0.9827 - val_loss: 0.0516
# Epoch 20/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.9846 - loss: 0.0461 - val_accuracy: 0.9855 - val_loss: 0.0440
# Epoch 21/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.9862 - loss: 0.0418 - val_accuracy: 0.9862 - val_loss: 0.0442
# Epoch 22/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.9857 - loss: 0.0427 - val_accuracy: 0.9829 - val_loss: 0.0545
# Epoch 23/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.9863 - loss: 0.0422 - val_accuracy: 0.9877 - val_loss: 0.0399
# Epoch 24/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - accuracy: 0.9869 - loss: 0.0394 - val_accuracy: 0.9851 - val_loss: 0.0481
# Epoch 25/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 174ms/step - accuracy: 0.9869 - loss: 0.0393 - val_accuracy: 0.9860 - val_loss: 0.0434
# Epoch 26/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 176ms/step - accuracy: 0.9883 - loss: 0.0350 - val_accuracy: 0.9848 - val_loss: 0.0516
# Epoch 27/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9882 - loss: 0.0346 - val_accuracy: 0.9866 - val_loss: 0.0449
# Epoch 28/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.9901 - loss: 0.0307 - val_accuracy: 0.9882 - val_loss: 0.0381
# Epoch 29/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 174ms/step - accuracy: 0.9905 - loss: 0.0287 - val_accuracy: 0.9877 - val_loss: 0.0440
# Epoch 30/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 174ms/step - accuracy: 0.9910 - loss: 0.0276 - val_accuracy: 0.9859 - val_loss: 0.0508
# Epoch 31/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 174ms/step - accuracy: 0.9906 - loss: 0.0285 - val_accuracy: 0.9864 - val_loss: 0.0463
# Epoch 32/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 174ms/step - accuracy: 0.9910 - loss: 0.0276 - val_accuracy: 0.9871 - val_loss: 0.0414
# Epoch 33/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.9913 - loss: 0.0268 - val_accuracy: 0.9853 - val_loss: 0.0458
# Epoch 34/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 174ms/step - accuracy: 0.9904 - loss: 0.0296 - val_accuracy: 0.9866 - val_loss: 0.0471
# Epoch 35/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - accuracy: 0.9914 - loss: 0.0266 - val_accuracy: 0.9875 - val_loss: 0.0439
# Epoch 36/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 174ms/step - accuracy: 0.9916 - loss: 0.0250 - val_accuracy: 0.9874 - val_loss: 0.0441
# Epoch 37/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.9920 - loss: 0.0254 - val_accuracy: 0.9881 - val_loss: 0.0451
# Epoch 38/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - accuracy: 0.9929 - loss: 0.0221 - val_accuracy: 0.9876 - val_loss: 0.0447
# Epoch 39/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - accuracy: 0.9930 - loss: 0.0222 - val_accuracy: 0.9868 - val_loss: 0.0486
# Epoch 40/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 194ms/step - accuracy: 0.9932 - loss: 0.0205 - val_accuracy: 0.9890 - val_loss: 0.0399
# Epoch 41/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.9942 - loss: 0.0178 - val_accuracy: 0.9899 - val_loss: 0.0435
# Epoch 42/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9941 - loss: 0.0186 - val_accuracy: 0.9882 - val_loss: 0.0403
# Epoch 43/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - accuracy: 0.9942 - loss: 0.0183 - val_accuracy: 0.9898 - val_loss: 0.0434
# Epoch 44/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.9942 - loss: 0.0177 - val_accuracy: 0.9881 - val_loss: 0.0471
# Epoch 45/45
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - accuracy: 0.9946 - loss: 0.0164 - val_accuracy: 0.9892 - val_loss: 0.0507
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9904 - loss: 0.0407
# Test accuracy: 99.04%

# %% [markdown]
# ### Load the trained model and evaluate accuracy of the trained model

# %%
model = A2.load_model(path, plot=True)
A2.model_eval(model, x_test, y_test)
# Out:
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.9905 - loss: 0.0403
# loss:  0.04030122607946396 accuracy:  0.9905465245246887
# Test accuracy: 99.05%

# %% [markdown]
# # Prediction

# %%
prediction = model.predict(x_test, verbose=1)
# Out:
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step

# %%
pred_img_num = 900
image = np.squeeze(x_test[pred_img_num,:,:,0])
#print("Model output:", (prediction[pred_img_num,:]))
print("Ground-truth:", np.array(y_test[pred_img_num,:]))
print("Predictions : [" + " ".join(["{:.0f}".format(val) for val in prediction[pred_img_num]]) + "]")

plt.imshow(image)
plt.show()

label = np.array(["{:.0f}".format(val) for val in prediction[pred_img_num]]).astype(float)
print("Predictions :", A1.read_label(label))
# Out:
# Ground-truth: [0 1 1 0 1 0 1 0]
# Predictions : [0 1 1 0 1 0 1 0]
# Predictions : Donut, Edge_Loc, Loc, Scratch,

# %%
pred_img_num = 500
image = np.squeeze(x_test[pred_img_num,:,:,0])
#print("Model output:", (prediction[pred_img_num,:]))
print("Ground-truth:", np.array(y_test[pred_img_num,:]))
print("Predictions : [" + " ".join(["{:.0f}".format(val) for val in prediction[pred_img_num]]) + "]")

plt.imshow(image)
plt.show()

label = np.array(["{:.0f}".format(val) for val in prediction[pred_img_num]]).astype(float)
print("Predictions :", A1.read_label(label))
# Out:
# Ground-truth: [0 0 1 0 1 0 0 0]
# Predictions : [0 0 1 0 1 0 0 0]
# Predictions : Edge_Loc, Loc,

# %%
pred_img_num = 3000
image = np.squeeze(x_test[pred_img_num,:,:,0])
#print("Model output:", (prediction[pred_img_num,:]))
print("Ground-truth:", np.array(y_test[pred_img_num,:]))
print("Predictions : [" + " ".join(["{:.0f}".format(val) for val in prediction[pred_img_num]]) + "]")

plt.imshow(image)
plt.show()

label = np.array(["{:.0f}".format(val) for val in prediction[pred_img_num]]).astype(float)
print("Predictions :", A1.read_label(label))
# Out:
# Ground-truth: [0 0 0 1 1 0 1 0]
# Predictions : [0 0 0 1 1 0 1 0]
# Predictions : Edge_Ring, Loc, Scratch,
